# %% [markdown]
# # 폴더 구조 변경
# ![image.png](attachment:image.png)

# %% [markdown]
# # routes
#     - 1. Authentication : 비 로그인시, 로그인을 위한 부분을 보여줌 -> Home으로 이동

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 현재 구조
#
# - index.js
#     - App
#         - Router
