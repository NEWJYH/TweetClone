# %% [markdown]
# # github page deploy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### package.json
# #### 추가사항
# ![image.png](attachment:image.png)

# %% [markdown]
# # 배포하는데 가장 최선의 방법?
#
# ```shell
#     yarn add gh-pages
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # deploy 추가

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # prebuild 추가

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # yarn deploy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 제 경우에는 깃헙 레포지토리 Settings > Options > GitHub Pages 에서 source를 gh-pages 브랜치로 바꿔주니 해결됐습니다!
